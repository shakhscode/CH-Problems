# %%
# import pnadas 
import pandas as pd

#load the dataset
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ### Peform one - hot encoding
# The dataset imported here is already encoded.
#
# But if you need to encode it you can use the following code, when the output is in categorical feature

# %%
#import the required module from sklearn
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ### Sort features X and class label y

# %%
#features x
X = df.iloc[:,:-1]
print(X.shape)

#class labels y 
y = df.iloc[:,-1]
print(y.shape)
# Out:
# (1599, 11)
# (1599,)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# ### Split the data into train and test

# %%
#import the required module from sklearn
from sklearn.model_selection import train_test_split

# define a function to make it easier future use
def trianSets(X, y, split_ratio):
        
        x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=split_ratio, random_state=614 , shuffle=True)
        return x_train, x_test, y_train, y_test

#split with a ratio of 80:20 i.e, split size = 0.2

X_train, X_test, y_train, y_test = trianSets(X,y,0.2)

# %% [markdown]
# ### Desing and train the neural network

# %%
#import the required libraiies and modules
from tensorflow.keras.models import Sequential       # Do design a neural network sequentially
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-58b2ed7e9066> in <module>
#       1 #import the required libraiies and modules
# ----> 2 from tensorflow.keras.models import Sequential       # Do design a neural network sequentially
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Import `Dense` from `keras.layers`
from keras.layers import Dense

# Initialize the constructor
model = Sequential()

# Add an input layer
model.add(Dense(12, activation ='relu', input_shape =(11, )))

# Add one hidden layer
model.add(Dense(9, activation ='relu'))

# Add an output layer
model.add(Dense(1, activation ='sigmoid'))

# Model output shape
model.output_shape

# Model summary
model.summary()

# Model config
model.get_config()

# List all weight tensors
model.get_weights()
model.compile(loss ='binary_crossentropy',
optimizer ='adam', metrics =['accuracy'])

# %%
from matplotlib import pyplot as plt

# %%
x = ['strawberry', 'vanilla', 'lemon', 'cookie dough']
y = [3,1,1,7]

plt.bar(x,y)
plt.xlabel('Flavor')
plt.ylabel('Frequency')
plt.ylim([0,8])
# Out:
# (0.0, 8.0)
