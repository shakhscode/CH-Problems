# %%
# import the libraries and the dataset
import pandas as pd
df = pd.read_excel('ckd.xlsx')
df
# Out:
#       age    bp    sg   al   su     rbc        pc         pcc          ba  \
# 0    48.0  80.0  1.02  1.0  0.0     NaN    normal  notpresent  notpresent
# 1     7.0  50.0  1.02  4.0  0.0     NaN    normal  notpresent  notpresent
# 2    62.0  80.0  1.01  2.0  3.0  normal    normal  notpresent  notpresent
# 3    48.0  70.0  1.01  4.0  0.0  normal  abnormal     present  notpresent
# 4    51.0  80.0  1.01  2.0  0.0  normal    normal  notpresent  notpresent
# ..    ...   ...   ...  ...  ...     ...       ...         ...         ...
# 382  55.0  80.0  1.02  0.0  0.0  normal    normal  notpresent  notpresent
# 383  42.0  70.0  1.03  0.0  0.0  normal    normal  notpresent  notpresent
# 384  12.0  80.0  1.02  0.0  0.0  normal    normal  notpresent  notpresent
# 385  17.0  60.0  1.03  0.0  0.0  normal    normal  notpresent  notpresent
# 386  58.0  80.0  1.03  0.0  0.0  normal    normal  notpresent  notpresent
#
#        bgr  ...   pcv    wbcc  rbcc  htn   dm  cad  appet   pe  ane   class
# ...

# %%
# filter the data where class  = "ckd"
df_filtered = df[df['class']=='ckd']
df_filtered
# Out:
#       age     bp    sg   al   su       rbc        pc         pcc          ba  \
# 0    48.0   80.0  1.02  1.0  0.0       NaN    normal  notpresent  notpresent
# 1     7.0   50.0  1.02  4.0  0.0       NaN    normal  notpresent  notpresent
# 2    62.0   80.0  1.01  2.0  3.0    normal    normal  notpresent  notpresent
# 3    48.0   70.0  1.01  4.0  0.0    normal  abnormal     present  notpresent
# 4    51.0   80.0  1.01  2.0  0.0    normal    normal  notpresent  notpresent
# ..    ...    ...   ...  ...  ...       ...       ...         ...         ...
# 232  48.0  100.0   NaN  NaN  NaN       NaN       NaN  notpresent  notpresent
# 233  48.0  110.0  1.02  3.0  0.0  abnormal    normal     present  notpresent
# 234  54.0   90.0  1.03  1.0  0.0    normal  abnormal  notpresent  notpresent
# 235  59.0   70.0  1.01  1.0  3.0  abnormal  abnormal  notpresent  notpresent
# 236  56.0   90.0  1.01  4.0  1.0    normal  abnormal     present  notpresent
#
# ...

# %%
# Extract the only age column
ageCol = df_filtered['age']

# %%
quantiles = ageCol.quantile([0.75, 0.25])
print(quantiles)

print(quantiles.iat[0])
print(quantiles.iat[1])
# Out:
# 0.75    65.25
# 0.25    47.75
# Name: age, dtype: float64
# 65.25
# 47.75

# %%
#import the pandas library
import pandas as pd

#import the dataset
df = pd.read_excel('ckd.xlsx')


#Now define a fucntion that does the task what you need.
#If you don't want the function just remove the function and use the code normally

def calculateIQR(df, condition):

    # first filter the dataset according to the condition
    df_filtered = df[df['class']==condition]

    # Extract  only the age column
    ageCol = df_filtered['age']

    #Now calculate 75th and 25th percentile
    quantiles = ageCol.quantile([0.75, 0.25])   #this is the syntax to calcualte any percentile.

    #calcualte iqr
    iqr = quantiles.iat[0] -quantiles.iat[1]

    print(f"IQR for  class = '{condition}' is {iqr} ")
    

#Run the function for class = 'ckd'
iqr_ckd = calculateIQR(df,'ckd')

#Run the function for class = 'notckd'
iqr_notckd = calculateIQR(df,'notckd')
# Out:
# IQR for  class = 'ckd' is 17.5
# IQR for  class = 'notckd' is 24.0

# %%
# create a list with 4 tv shows
shows = ['Family Feud','The Allen Show','Americas Got Talend','The voice']

#print the list
print(f'Previous list: \n {shows}')

#Take input from the user
inp = input('Enter you favourite show, position:')

print('Your input:',inp)

# split the input to extract the show title and the desire position to enter it
inputs = inp.split(',')

# Extract the title
new_show = inputs[0]

#Extract tehe position and convert it into an integer
position = int(inputs[1])

#If the position is negative make it as 0 so that the new_show will be added in the first position
if position<0:
    position = 0
# if position exceeds the count of the total shows then make it to the last position
elif position> len(shows):
    position = len(shows)
else: 
    pass

#Now add the new_show to the desired position
shows.insert(position, new_show)

#print the updated shows
print(f'Updated list: \n {shows}')
# Out:
# Previous list:
#  ['Family Feud', 'The Allen Show', 'Americas Got Talend', 'The voice']
# Your input: Grey's Academy,-2
# Updated list:
#  ["Grey's Academy", 'Family Feud', 'The Allen Show', 'Americas Got Talend', 'The voice']
